# %%
p = "/home/shibaev/diff/mdlm/multirun_star_shape_seqlen128/2025-09-22/08-46-27/0_steps=128_p=0.9_t=1.0_t_on=0.3_t_off=0.0_noise=loglinear/sampling_trajectories/282061/traj_2.jsonl"
p = "/home/shibaev/diff/mdlm/multirun_star_shape_seqlen128/2025-09-22/08-46-27/1_steps=128_p=0.9_t=1e+100_t_on=0.3_t_off=0.0_noise=loglinear/sampling_trajectories/497623/traj_2.jsonl"

t_from = 0.31
t_to = 0.25
first_n_symbols = 100

import json

with open(p, 'r') as f:
    for line in f:
        data = json.loads(line)
        t = data['t']
        t = float(t)
        if t <= t_from and t >= t_to:
            x_t = data['x']
            x_0 = data['x0']

            x_t = x_t[:first_n_symbols]
            x_0 = x_0[:first_n_symbols]

            print(t)
            print(x_t)
            print(x_0)
            print()
# Out:
# 0.304694
# [MASK]It's[MASK] late to a[MASK][MASK] mostly silent in many quarters,[MASK] traitors, Republicans[M
# [MASK][MASK][MASK][MASK][MASK][MASK][MASK][MASK][MASK] mostly[MASK][MASK][MASK][MASK][MASK][MASK] tr
#
# 0.296882
# [MASK]It's too late to[MASK] period and mostly[MASK] in[MASK] quarters[MASK][MASK] traitors, Republi
# <|endoftext|>It's too late to a period and mostly silent in many quarters, only traitors, Republican
#
# 0.28907
# <|endoftext|>It's too[MASK][MASK] talk period[MASK][MASK], in public quarters[MASK] our traitors[MAS
# <|endoftext|>It's too late to talk period and mostly, in public quarters, our traitors, Republicans
#
# 0.281257
# <|endoftext|>It's too late[MASK] talk period.[MASK],[MASK][MASK] quarters,[MASK] traitors[MASK][MASK
# <|endoftext|>It's too late to talk period. but, in public quarters, our traitors, Republicans and De
#
# 0.273445
# <|endoftext|>It's too late to talk period. Liberals[MASK] in[MASK] quarters[MASK][MASK] traitors of,
# <|endoftext|>It's too late to talk period. Liberals, in some quarters, the traitors of, and, of fear
#
# 0.265632
# <|endoftext|>[MASK]'s[MASK] late to talk period[MASK] Liberals, in[MASK] quarters seen[MASK] tra[MAS
# <|endoftext|>It's too late to talk period. Liberals, in many quarters seen are traitors of, and, of
#
# 0.25782
# <|endoftext|>It[MASK] too late[MASK] talk period. Liberals, in[MASK] quarters seen[MASK][MASK][MASK]
# <|endoftext|>It's too late to talk period. Liberals, in some quarters seen the trappings of, and, of
#
# 0.250008
# <|endoftext|>It[MASK] too late to talk period[MASK] Liberals, in[MASK][MASK][MASK] as[MASK] are conc
# <|endoftext|>It's too late to talk period. Liberals, in all quarters seen as, are concern, and, of f
